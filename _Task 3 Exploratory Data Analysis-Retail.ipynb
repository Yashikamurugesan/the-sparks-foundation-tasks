# %% [markdown]
# # TASK 3

# %% [markdown]
# # Exploratory Data Analysis-Retail

# %% [markdown]
# # Author: YASHIKA MURUGESAN

# %% [raw]
# Perform 'Exploratory Data Analysis' on dataset 'SampleSuperStore', finding out the weak areas to work on to make more profit.

# %% [raw]
# Dataset: https://bit.ly/3i4rbWl

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("F:/foundation project/SampleSuperstore.csv")

# %%
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
  data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
data.shape
# Out:
# (9994, 13)

# %%
data.size
# Out:
# 129922

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(data['Sales'],color='red',label='Sales',shade=True,bw=25)
sns.kdeplot(data['Profit'],color='Blue',label='Profit',shade=True,bw=25)
plt.xlim([-100,1000])
plt.legend()
# Out:
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [raw]
# Profit is more than that of sale but there are some areas where profit could be increased

# %% [markdown]
# # Analysis Using pairplot of each column

# %% [markdown]
# ### Based on the category

# %%
sns.pairplot(data,hue="Category")

# %%
data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# ## Heatmap for Correlation

# %%
sns.heatmap(data.corr(),cmap="rocket_r",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## From  the above Heatmap:

# %% [raw]
# Sales and profit are moderately correlated.
# Discount and profit and negatively correlated.
# Quantity and profit are less moderately correlated.

# %% [markdown]
# ## Count plot of each column

# %%
fig,axs=plt.subplots(nrows=2,ncols=2,figsize=(10,7));

sns.countplot(data['Category'],ax=axs[0][0])
sns.countplot(data['Segment'],ax=axs[0][1])
sns.countplot(data['Ship Mode'],ax=axs[1][0])
sns.countplot(data['Region'],ax=axs[1][1])
axs[0][0].set_title('Category',fontsize=20)
axs[0][1].set_title('Segment',fontsize=20)
axs[1][0].set_title('Ship Mode',fontsize=20)
axs[1][1].set_title('Region',fontsize=20)

plt.tight_layout()
# Out:
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(20,8))
sns.countplot(data['Sub-Category'])
plt.title('Sub-Category',fontsize=20)
# Out:
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Sub-Category')

# %%
plt.figure(figsize=(18,5))
sns.countplot(data['Quantity'])
plt.title("Quantity",fontsize=20)
# Out:
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Quantity')

# %%
plt.figure(figsize=(18,5))
sns.countplot(data['Discount'])
plt.xticks(rotation=90)
plt.title("Discount",fontsize=20)
# Out:
# D:\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Discount')

# %% [markdown]
# ## Distribution of the data using the plot

# %%
fig,axs=plt.subplots(ncols=2, nrows=2, figsize=(10,10))

sns.displot(data["Sales"],color='red', ax=axs[0][0])
sns.displot(data["Profit"],color='green', ax=axs[0][1])
sns.displot(data["Quantity"],color='orange', ax=axs[1][0])
sns.displot(data["Discount"],color='blue', ax=axs[1][1])
axs[0][0].set_title('Sales Distribution', fontsize=20)
axs[0][1].set_title('Profit Distribution', fontsize=20)
axs[1][0].set_title('Quantity Distribution', fontsize=20)
axs[1][1].set_title('Discount Distribution', fontsize=20)
plt.show()
# Out:
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# D:\anaconda3\lib\site-packages\seaborn\distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Statewise Deal Analysis

# %%
data['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
data_1=data['State'].value_counts()
data_1.head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
data_1.plot(kind='bar',figsize=(15,5))
plt.ylabel("Frequency / Number og deals")
plt.xlabel("States")

plt.title("State wise dealing ", fontsize=20)
plt.show()

# %% [markdown]
# ### Here is top 3 state where deals as Highest.

# %% [markdown]
# Califonia
# New York
# Texas

# %% [markdown]
# ### Wyoming: Lowest Number of DEAL

# %%
data['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %% [markdown]
# ### Average number of deal per state is 204

# %% [markdown]
# ### City wise analysis of the dealing

# %%
data_2=data['City'].value_counts()
data_2.head(50)
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
# Houston          377
# Chicago          314
# Columbus         222
# San Diego        170
# Springfield      163
# Dallas           157
# Jacksonville     125
# Detroit          115
# Newark            95
# Richmond          90
# Jackson           82
# Columbia          81
# Aurora            68
# Phoenix           63
# Long Beach        61
# Arlington         60
# San Antonio       59
# Miami             57
# Louisville        57
# Rochester         53
# Charlotte         52
# Henderson         51
# Lakewood          49
# Lancaster         46
# Milwaukee         45
# Fairfield         45
# Lawrence          44
# Denver            44
# Baltimore         43
# San Jose          42
# Cleveland         42
# Pasadena          42
# Fayetteville      41
# Salem             40
# Austin            39
# Atlanta           39
# Franklin          37
# Tampa             36
# ...

# %%
data_2.plot(kind='bar',figsize=(15,5))
plt.ylabel("Frequency / Number of deals")
plt.xlabel("City")

plt.title("City wise dealing ", fontsize=20)
plt.show()

# %% [markdown]
# ### Here is top 3 city where deals are highest.

# %% [markdown]
# New York City
# Los Angeles
# Philadelphla

# %%
data['City'].value_counts().mean()
# Out:
# 18.821092278719398

# %% [markdown]
# ### Average number of deal per city is 19.

# %% [markdown]
# ### Segment wise analysis of profit, Discount and sell

# %%
data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
data_segment= data.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
data_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
data_segment.plot.pie(subplots=True, autopct='%1.1f%%', figsize=(18,20), startangle=10, shadow=True, labels= data_segment.index)
plt.title('Segment wise analysis of sale, Discount, Profit')
# Out:
# D:\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# Text(0.5, 1.0, 'Segment wise analysis of sale, Discount, Profit')

# %% [markdown]
# Sales:
#
#    consumer:32%
#    corporate:33.5%
#    Home office:34.5%

# %% [markdown]
# Discount:
#
#    consumer:15.8%
#    corporate:15.8%
#    Home office:14.7%

# %% [markdown]
# Profit:
#
#    consumer:15.8%
#    corporate:15.8%
#    Home office:14.7%

# %% [markdown]
# ### Statewise analysis of profit Discount and sell

# %%
data['State'].value_counts().head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
data_state=data.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
data_state.head(10)
# Out:
#                            Sales  Discount      Profit
# State
# Alabama               319.846557  0.000000   94.865989
# Arizona               157.508933  0.303571  -15.303235
# Arkansas              194.635500  0.000000   66.811452
# California            228.729451  0.072764   38.171608
# Colorado              176.418231  0.316484  -35.867351
# Connecticut           163.223866  0.007317   42.823071
# Delaware              285.948635  0.006250  103.930988
# District of Columbia  286.502000  0.000000  105.958930
# Florida               233.612815  0.299347   -8.875461
# Georgia               266.825217  0.000000   88.315453

# %%
data_state1=data_state.sort_values('Profit')

data_state1[['Profit']].plot(kind='bar', figsize=(15,4))
plt.ylabel("Profit per state")
plt.xlabel("States")

plt.title("State wise profit nalysis ", fontsize=20)
plt.show()

# %% [markdown]
# # RESULT

# %% [markdown]
# Vermont: Hidheest profit
# Ohio: Lowest profit

# %% [markdown]
# ## Statewise Sales Analysis

# %%
data_state['Sales'].plot(kind='pie', autopct='%1.1f%%', figsize=(20,20), startangle=90, shadow=True, )
plt.title('State wise analysis of sale', fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of sale')

# %% [markdown]
# Highest amount of sales= Wyoming(11.8%) Lowest amount of sales=South Dakota(0.8%)

# %% [markdown]
# ### Statewise Discount Analysis

# %%
data_state1['Discount'].plot(kind='bar', figsize=(18,5))
plt.title("State wise analysis of Discount", fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Discount')

# %% [markdown]
# ## Illinois at the top

# %% [markdown]
# ### Citywise analysis of the profile

# %%
data_city=data.groupby(['City'])[['State', 'Discount', 'Profit']].mean()
data_city=data_city.sort_values("Profit")
data_city.head()
# Out:
#             Discount      Profit
# City
# Bethlehem   0.380000 -200.619160
# Champaign   0.600000 -182.352000
# Oswego      0.600000 -178.709200
# Round Rock  0.274286 -169.061614
# Lancaster   0.315217 -157.371052

# %%
data_city['Profit'].head(30).plot(kind='bar', figsize=(15,5),color='black')
# Out:
# <AxesSubplot:xlabel='City'>

# %%
data_city['Profit'].tail(30).plot(kind='bar', figsize=(15,5),color='black')
plt.title("city wise analysis of sale, Discount, Profit")
# Out:
# Text(0.5, 1.0, 'city wise analysis of sale, Discount, Profit')

# %% [markdown]
# 30 Cities which has profit in positive
# 30 Cities which has profit in negative
# The balance is pretty good here

# %% [markdown]
# ## Quantity wise sales, profit and discount analysis

# %%
data_quantity=data.groupby(['Quantity'])[['Sales', 'Discount', 'Profit']].mean()
data_quantity.head(10)
# Out:
#                Sales  Discount     Profit
# Quantity
# 1          59.234632  0.152959   8.276396
# 2         120.354488  0.154858  16.006831
# 3         175.201578  0.153329  23.667715
# 4         271.764059  0.157708  37.131310
# 5         337.936339  0.157146  40.257394
# 6         362.101960  0.166556  18.051517
# 7         395.888393  0.161980  56.579163
# 8         458.210802  0.171595  42.244342
# 9         498.083683  0.147946  68.557716
# 10        422.046737  0.190702  35.862404

# %%
data_quantity.plot.pie(subplots=True , autopct='%1.1f%%', figsize=(20,20), startangle=90, shadow=True, labels=data_quantity.index)
plt.title('Quantity wise analysis of sale', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Quantity wise analysis of sale')

# %% [markdown]
# 13 Number of Quantity is high for sales and profit.

# %% [markdown]
# ## Catagroy wise sales discount and profit

# %%
data_category=data.groupby(['Category'])[['Sales','Discount','Profit']].mean()
data_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
data_category.plot.pie(subplots=True, figsize=(18,20),autopct='%1.1f%%',labels=data_category.index)
# Out:
# D:\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# Maximun sales and profit obtain in Technology.
# Minimun profit obtain in Furniture

# %% [markdown]
# ### Sub-Category wise sales , profit and discount

# %%
data_sub_category=data.groupby(['Sub-Category'])[['Sales','Discount','Profit']].mean()
data_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %% [markdown]
# ## Based on the sales

# %%
plt.figure(figsize=(15,15))
plt.pie(data_sub_category['Sales'], labels= data_sub_category.index, autopct='%1.1f%%')
plt.title("sub_category wise sales analysis", fontsize=20)
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Copier then machine have high sales

# %% [markdown]
# ## Based on the Discount

# %%
plt.figure(figsize=(15,15))
plt.pie(data_sub_category['Discount'], labels= data_sub_category.index, autopct='%1.1f%%')
plt.title("sub_category wise Discount analysis", fontsize=20)
plt.legend()
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Binders, Machines and then tables have high Discount.

# %% [markdown]
# ### Based on the profit

# %%
data_sub_category.sort_values('Profit')[['Sales', 'Profit']].plot(kind='bar',figsize=(10,5),label=['avg sales price($)','Profit($)'])
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %% [markdown]
# ## Copier : Highest profit as well as sell

# %% [markdown]
# ### Region wise analysis

# %%
data_region=data.groupby(['Region'])[['Sales','Discount','Profit']].mean()
data_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %%
data_region.plot.pie(subplots=True, figsize=(18,20), labels= data_region.index, autopct='%1.1f%%')
# Out:
# D:\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# ## West: Profit is high

# %% [markdown]
# Ship mode wise analysis

# %%
data['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
data_shipmode= data.groupby(['Ship Mode'])[['Sales', 'Discount', 'Profit']].mean()

# %%
data_shipmode.plot.pie(subplots=True, figsize=(18,20), labels= data_shipmode.index)
# Out:
# D:\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:1583: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   results = ax.pie(y, labels=blabels, **kwds)
# array([<AxesSubplot:ylabel='Sales'>, <AxesSubplot:ylabel='Discount'>,
#        <AxesSubplot:ylabel='Profit'>], dtype=object)

# %% [markdown]
# Profit and discount is high in first class
# Sales is high fot same day ship

# %% [markdown]
# ## Result and conclusion

# %% [markdown]
# profit is more than that of sale but there are some areas profit could be increased
# profit and discount is high in first class
# sales is high for some day ship
# sub-category: copier-high profit & sales
# category: minimun sales and profit obtain in furniture
# sate vermont: hight profit
